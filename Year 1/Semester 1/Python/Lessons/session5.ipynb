# %% [markdown]
# # Introduction

# %% [markdown]
# A **computer program** is a sequential **set of instructions** written in a **computer language** that is used to direct the computer to **perform a specific task of computation**. The objective of programming is to solve problems using computers quickly and accurately.
#
#
# * A **problem** is a situation where the desired outcome is not immediately accessible.
#
# * To **achieve** the **desired result**, a **sequence of steps** involving **arithmetic calculations** or **logical reasoning** is necessary.
#
# * According to the **law of equifinality**, the same objective can be reached through various actions and different approaches, meaning the same outcome can be obtained in multiple ways.
#
#
# * The different ways of solving a problem are called **solution** **strategies**.
#
# * This **most effective way** is called the **optimum way**.
#
# * The optimum way of solving a problem to get the desired result can be
# achieved by analyzing different strategies for the solution and then selecting the way that can yield the result in the least time using the minimum amount of resources. The selection process will depend on the efficiency of the person and his/her understanding of the problem.
#
#
# * A **set of steps** that generates a **finite sequence** of elementary **computational operations** leading to the **solution** of a given **problem** is called an **algorithm**.
# * Algorithms can sometimes be too lengthy and complex to follow, making their textual descriptions difficult to understand quickly.
# * To overcome this, a **visual representation** can be used as an alternative, known as a **flowchart**.
# * **Flowcharts** offer a **clearer** and more **intuitive** way to depict the steps of an algorithm.

# %% [markdown]
# #What is a flowchart?

# %% [markdown]
# *   A **flowchart** is a **schematic representation** of an **algorithm** or process.
# *   A flowchart can also be defined as a **graphical representation** of an algorithm, a step-by-step approach to solving a task.
# *   A flowchart is a **diagram that illustrates the steps, sequences, and decisions** of a process or workflow.
#
#
# ---
#
# *   It helps you to organise your thoughts
#
#
# *   It helps you to organise the process
#
# ![Flowchart-Advantages-Infographic.png](data:image/png;base64,...)

# %% [markdown]
# *  A program flowchart is a highly valuable tool in program development.
#
# * It provides a visual representation of a program's logic, making it easier to spot errors or omissions compared to reviewing the program code alone.
# * Additionally, a flowchart allows for quicker and clearer understanding of the program’s flow.
#
# * It also serves as a form of documentation, which can be incredibly useful when future modifications to the program are needed.

# %% [markdown]
# #Elements of a Flowchart

# %% [markdown]
# * In a flowchart, **various shapes** are used to **represent** different **types of operations**.
# * These **shapes** are **connected** by **lines with arrows** that indicate the **sequence or direction** of steps to be followed.
# * These **connecting lines** are called **flow lines** and guide the progression from one step to the next in the process.
#
# ![flowchart2.png](data:image/png;base64,...)

# %% [markdown]
# ![flowcharts3.png](data:image/png;base64,...)

# %% [markdown]
# # Examples

# %% [markdown]
# **Example** 1: A simple flowchart for exploring a dataset
#
# ![FLOWCHART4.png](data:image/png;base64,...)

# %% [markdown]
# **Example 2**
#
# ![Flowchart5.png](data:image/png;base64,...)

# %% [markdown]
# **Example 3**

# %% [markdown]
# ![flowchart6.png](data:image/png;base64,...)
